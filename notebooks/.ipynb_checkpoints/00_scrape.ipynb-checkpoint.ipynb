# %% [markdown]
# # 00 — Tweet Scraping Demo Notebook
#
# This notebook demonstrates how tweet scraping is implemented in the project
# using the `NitterScraper` and `DataCollector` modules.
#
# ⚠️ Note:
# This notebook **does not re-run full scraping**.
# It shows how the scraping *would* work and loads a sample CSV already produced.
#
# ## Objectives
# - Import scraping modules
# - Show scraper configuration
# - Load sample scraped output
#
# ---

# %%
from src.scraper.nitter_scraper import NitterScraper
from src.scraper.data_collector import DataCollector

# %%
# Example (not executed):
scraper = NitterScraper(username="ilyasut")
collector = DataCollector(scraper)

# collector.collect_tweets(limit=100)
# collector.export_to_csv("data/raw/ilyasut_tweets.csv")

# %%
import pandas as pd

df = pd.read_csv("data/raw/ilyasut_tweets.csv")
df.head()
